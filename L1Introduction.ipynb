# %% [markdown]
# # Introduction to Python

# %% [markdown]
# ### Basic Variables and how they work in Python

# %%
name = "SDds"

# %%
name
# Out:
# 'SDds'

# %%
str # shift + tab to get the document for the function
#help(str)

x = "Hello"
y = int(3)
#y = "Hello"
print(y)

# Python List
myList = ["car", "kin"]
myList2 = list(("Car", "kin"))
print(myList)

type(y)
# Out:
# 3
# ['car', 'kin']
# int

# %% [markdown]
# ### Conditions in Python

# %%
if y == 3:
    print("This worked")
# Out:
# This worked

# %% [markdown]
# ### Loops in python

# %%
x = 3
while x < 10:
    print(x)
    x+=1
    
for item in range(len(myList2)):
    for item
    print(myList2[item])
    
for item in myList:
    print(item)
# Out:
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# Car
# kin
# car
# kin

# %% [markdown]
# ## Python Classes and Methods
#
# ![classimg.png](attachment:classimg.png)

# %%
class Pokemon:
    
    def __init__(self, name, type, health):
        self.name = name
        self.type = type
        self.health = health
        
    def attack(self):
        print("{} makes an attack.".format(self.name))
        
    def dodge(self):
        print("{} dodges an attack".format(self.name))
        
    def evolve(self):
        print("{} evolves".format(self.name))

# %%
pikachu = Pokemon("Pikachu", "Electric", 70)
pikachu

# %%
#pikachu.attack()
pikachu.dodge()
# Out:
# Pikachu dodges an attack

# %% [markdown]
# # Introduction to Data Structures
#
# ## Types of Data Structures
#
# ### Primitive Data Structures
# - Primitive Data Structures directly operate according to the machine instructions. These are the primitive data types. Data types like int, char, float, double, and pointer are primitive data structures that can hold a single value.
#
# ### Non-Primitive Data Structures
# - Non-primitive data structures are complex data structures that are derived from primitive data structures

# %% [markdown]
# ![ds.png](attachment:ds.png)

# %%
s = [[1, 2, 3, 4], [1, 2, 3, 4]]
[list(map(str,i)) for i in s]
